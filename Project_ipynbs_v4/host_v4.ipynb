# %% [markdown]
# <h1>收容所管理员视角的数据库操作</h1>

# %%
# %load_ext sql

# %%
# %%sql postgresql://wangwu:123456@localhost:5432/project
#
# SET statement_timeout = 0;
# SET lock_timeout = 0;
# SET client_encoding = 'UTF-8';
# SET standard_conforming_strings = on;
# SET check_function_bodies = false;
# SET client_min_messages = warning;
# Out:
# Done.
# Done.
# Done.
# Done.
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO View_Shelter_Management (facility_name, facility_type, status_code, location_text)
# VALUES ('悦宠避难所', '收容所', 1, 'POINT(120.12 30.27)');
# Out:
#  * postgresql://wangwu:***@localhost:5432/project
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM View_Shelter_Management;
# Out:
#  * postgresql://wangwu:***@localhost:5432/project
# 3 rows affected.
# [(1, '萌宠爱心收容所', '其他收容所', 1, '营运中', 'POINT(116.4 39.9)'),
#  (2, '阳光宠物医院', '宠物医院', 1, '营运中', 'POINT(116.42 39.92)'),
#  (3, '悦宠避难所', '收容所', 1, '营运中', 'POINT(120.12 30.27)')]

# %%
# %%sql
# UPDATE View_Shelter_Management
# SET status_code = 0
# WHERE facility_name = '悦宠避难所';
# Out:
#  * postgresql://wangwu:***@localhost:5432/project
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM View_Shelter_Management;
# Out:
#  * postgresql://wangwu:***@localhost:5432/project
# 3 rows affected.
# [(1, '萌宠爱心收容所', '其他收容所', 1, '营运中', 'POINT(116.4 39.9)'),
#  (2, '阳光宠物医院', '宠物医院', 1, '营运中', 'POINT(116.42 39.92)'),
#  (3, '悦宠避难所', '收容所', 0, '暂停服务', 'POINT(120.12 30.27)')]
